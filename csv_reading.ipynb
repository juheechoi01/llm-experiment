# %%
import pandas as pd
df = pd.read_csv('simulation_sns/kobertopic_argument_topics.csv')
df.head()
# Out:
#                                  sim_id     condition  turn  point  topic_id  \
# 0  42bb2787-7fce-4b44-98c3-681084cda2f3  authorless-2     1      1         2
# 1  42bb2787-7fce-4b44-98c3-681084cda2f3  authorless-2     1      2         8
# 2  42bb2787-7fce-4b44-98c3-681084cda2f3  authorless-2     1      3        -1
# 3  42bb2787-7fce-4b44-98c3-681084cda2f3  authorless-2     2      1        28
# 4  42bb2787-7fce-4b44-98c3-681084cda2f3  authorless-2     2      2         5
#
#       topic_label    topic_keywords                                 text  \
# 0  소셜 미디어의 교육적 기능  없음, , , , , , ,            인터넷은 교육적 자원으로서 중요한 역할을 합니다
# 1     중독 문제 해결 방안  없음, , , , , , ,              사회적 소통의 경험은 중요한 성장 과정입니다
# 2     Noise (미분류)  없음, , , , , , ,              표현의 자유는 청소년에게도 중요한 권리입니다
# 3  예방과 교육의 지속 가능성  없음, , , , , , ,    부정적인 영향은 교육과 자율적인 사용법으로 완화할 수 있습니다
# 4   정보 보호와 가족의 역할  없음, , , , , , ,   가정 내에서의 부모와의 협력은 효과적인 해결책이 될 수 있습니다
#
#                                             subclaim
# ...

# %%
df[df['topic_id']==0]['text']
# Out:
# 28                     또한, 법안은 기술의 빠른 발전 속도를 따라잡지 못할 것입니다
# 54                        미성년자의 자기 표현과 창의력 발휘를 제한할 수 있습니다
# 56                         디지털 시대에 필수적인 기술을 학습할 기회를 억제합니다
# 69          법적 제한은 유연성이 떨어지며 변화하는 기술 환경에 발 빠르게 대응하기 어렵습니다
# 78      법적 규제는 오히려 기술의 발전과 적응을 늦추고, 미성년자들이 필요한 기술을 습득할...
#                               ...
# 1708         둘째, 유연한 법안 및 교육 프로그램 혼합은 정책의 일관성을 저해할 수 있습니다
# 1730          제한적인 접근은 디지털 기술에 대한 미성년자들의 이해도를 떨어뜨릴 수 있습니다
# 1734                              법적 제한은 역효과를 초래할 수도 있습니다
# 1766                        셋째, 제도적 금지는 우회되기 쉽고 실효성이 낮습니다
# 1768                            둘째, 법적 제한은 혁신을 저해할 수 있습니다
# Name: text, Length: 155, dtype: object

# %%
df_animal = pd.read_csv('simulation_2/kobertopic_argument_topics.csv')
df_animal.head()
# Out:
#                                  sim_id   condition  turn  point  topic_id  \
# 0  49e11e13-95b8-4415-a0ce-bb315072e4b7  authorless     1      1        -1
# 1  49e11e13-95b8-4415-a0ce-bb315072e4b7  authorless     1      2         7
# 2  49e11e13-95b8-4415-a0ce-bb315072e4b7  authorless     1      3        11
# 3  49e11e13-95b8-4415-a0ce-bb315072e4b7  authorless     2      1         4
# 4  49e11e13-95b8-4415-a0ce-bb315072e4b7  authorless     2      2        -1
#
#     topic_label    topic_keywords                                   text  \
# 0   Noise (미분류)  없음, , , , , , ,         동물 실험은 인체에 미칠 영향을 예측하는 데 필수적입니다
# 1   혁신적인 치료법 개발  없음, , , , , , ,                동물 실험은 과학적 발견의 기반을 마련합니다
# 2  임상 전 연구의 안전성  없음, , , , , , ,   동물 실험은 최종 사용자에게 안전한 결과물을 제공하는 데 중요합니다
# 3     대체 기술의 제한  없음, , , , , , ,     인공 장기나 컴퓨터 모델은 현재의 기술로는 아직 초기 단계입니다
# 4   Noise (미분류)  없음, , , , , , ,      동물 실험은 예측불가능한 문제점을 미리 식별하는 역할을 합니다
#
#                                             subclaim
# ...
